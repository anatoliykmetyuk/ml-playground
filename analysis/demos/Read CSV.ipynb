# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('data.csv', names=['X', 'Y', 'Z'], dtype={'X': np.int32, 'Y': np.int32, 'Z': np.float64})
# Out:
#         X   Y             Z
# 0     -50 -50  2.458335e+11
# 1     -50 -49  2.920578e+11
# 2     -50 -48  3.501054e+11
# 3     -50 -47  4.221749e+11
# 4     -50 -46  5.106278e+11
# 5     -50 -45  6.179065e+11
# 6     -50 -44  7.464259e+11
# 7     -50 -43  8.984379e+11
# 8     -50 -42  1.075875e+12
# 9     -50 -41  1.280182e+12
# 10    -50 -40  1.512138e+12
# 11    -50 -39  1.771694e+12
# 12    -50 -38  2.057825e+12
# 13    -50 -37  2.368417e+12
# 14    -50 -36  2.700204e+12
# 15    -50 -35  3.048759e+12
# 16    -50 -34  3.408545e+12
# 17    -50 -33  3.773040e+12
# 18    -50 -32  4.134924e+12
# 19    -50 -31  4.486318e+12
# 20    -50 -30  4.819077e+12
# 21    -50 -29  5.125109e+12
# 22    -50 -28  5.396705e+12
# 23    -50 -27  5.626869e+12
# 24    -50 -26  5.809611e+12
# 25    -50 -25  5.940200e+12
# 26    -50 -24  6.015358e+12
# 27    -50 -23  6.033381e+12
# 28    -50 -22  5.994188e+12
# 29    -50 -21  5.899295e+12
# ...    ..  ..           ...
# 10171  50  21  9.008180e+09
# ...
